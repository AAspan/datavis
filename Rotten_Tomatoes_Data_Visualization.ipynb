# %% [markdown]
# #About the Project
# This project will be based on the movies through time old and new. These movies have been reviewed through Rotten Tomatoes which shows reviews from critics and audiences the data will show the differences in opinions and how they correlate with the genres, movie titles, authors, and release date. The data will be visualized in an interactive way,
#
# #Project Goals
# The main goal of the project will be show movies in different ways based on,
# The contrast of movies throughout time. The differences in movie genres scores between critics and audiences. The best and worse movies by production company, actors, and genre. How actors help the ratings, and production company rate of success.

# %% [markdown]
# # ●	 Films Suggestions:
# This plot will utilize user selected sub-categories to find the film with the highest and lowest rated films. For example, a user can select sub-categories,i.e, genre, year, and/ or director, to find the highest or lowest rated movie that meets those specifications.

# %%
import pandas as pd
import numpy as np
import plotly.express as px

df= pd.read_csv("rotten_tomatoes_movies.csv")

highestrate = df.sort_values(by='tomatometer_rating', ascending =False)

newdf=highestrate[['movie_title','movie_info','content_rating','genres','directors','production_company','tomatometer_rating','tomatometer_count','tomatometer_fresh_critics_count']]
                
topTen=newdf.iloc[0:20,:]


fig = px.histogram(topTen, x="tomatometer_count", y="tomatometer_fresh_critics_count", color="genres", marginal="box",
                   hover_data=["movie_title","movie_info"])
fig.show()

fig2 = px.histogram(topTen, x="tomatometer_count", y="tomatometer_fresh_critics_count", color="directors", marginal="box",
                   hover_data=["movie_title","movie_info"])
fig2.show()

fig3 = px.histogram(topTen, x="tomatometer_count", y="tomatometer_fresh_critics_count", color="content_rating", marginal="box",
                   hover_data=["movie_title","movie_info"])
fig3.update_layout(title_text='idk')
fig3.show()

topHigh =newdf.iloc[0:4,:]
fig3 = px.histogram(topHigh, x="tomatometer_count", y="tomatometer_fresh_critics_count", color="production_company", marginal="box",
                   hover_data=["movie_title","movie_info"])
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # ● Find My Audience
# This plot is for movie producers who want to determine if their movie will bring in a large audience and to determine what kinds of movies bring in the largest audiences.

# %%
import pandas as pd
import numpy as np
import plotly.express as px

df= pd.read_csv("rotten_tomatoes_movies.csv")
df.dropna()

highestrate = df.sort_values(by='tomatometer_rating', ascending =False)

newdf=highestrate[['movie_title','movie_info','content_rating','runtime','genres','directors','production_company',
                   'original_release_date','audience_rating','audience_count','audience_status']]
upRight=newdf.loc[newdf["audience_status"] == "Upright"]    

topTen=upRight.iloc[0:10,:]

fig = px.scatter(topTen, x="audience_rating", y="audience_count",    size="audience_rating", color="genres",
                  size_max=20)
fig.show()

topHigh =newdf.iloc[0:4,:]
fig = px.scatter(topHigh, x="audience_rating", y="audience_count",    size="audience_rating", color="production_company",
                  size_max=5)

fig.show()
fig = px.scatter(topTen, x="audience_rating", y="audience_count",    size="audience_rating", color="directors",
                  size_max=20)

fig.show()

fig = px.scatter(topTen, x="audience_rating", y="audience_count",    size="audience_rating", color="content_rating",
                  size_max=20)

fig.show()
fig = px.scatter(topTen, x="audience_rating", y="audience_count",    size="audience_rating", color="content_rating",
                  size_max=20)

fig.show()
"""group by [audience_status=uplift][] """""
"""remove rows with spilled or no audience status"""
"""top 10"""
"""FacetGrid"""
"""tool tip = "movie_info"""
"""x axis="[audience_status||audience_count]"""
"""Y axis = (interactive), year, genre, actor,contnent rating3 etc."""
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# This example shows the top ten movies based on the run time.
# It shows the runtime has the main decider on which movie has the runtimes.

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import numpy as np
import plotly.express as px
   
df = pd.read_csv("rotten_tomatoes_movies.csv").head(10)
x=df.iloc[:,1]#movie title
y=df.iloc[:,11]#movie runtime
plt.title('movie titles and their runtime')
plt.xlabel('movie titles')
plt.ylabel('runtime')
plt.plot(x,y)
plt.show()

# %% [markdown]
# This chart shows the relation between the tomatometer rating and audience rating. It shows that how both the tomatometer and audience ratings go againts each other which is why the data shows as indirect lines.

# %%
import pandas as pd
import plotly.graph_objects as go

df = pd.read_csv('rotten_tomatoes_movies.csv').head(50)

fig = go.Figure(go.Scatter(x = df['tomatometer_rating'], y = df['audience_rating'],
                  name='tomatometer and audience'))

fig.update_layout(title='Rating of tomatometer ratig vs audience rating',
                   plot_bgcolor='rgb(230, 230,230)',
                   showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In this chart the top ten movies are based on the rated version of the movies.It shows the amount each movie rate has in the csv file.

# %%
import plotly
import plotly.graph_objs as go
import plotly.express as px
import seaborn as sns
from plotly.offline import download_plotlyjs, plot, init_notebook_mode, iplot
df = pd.read_csv("rotten_tomatoes_movies.csv")
print(df["content_rating"].value_counts()[:10])
plt.figure(figsize=(12,6))
sns.countplot(y='content_rating',data = df,order =df["content_rating"].value_counts().index[0:10],palette="pastel")
plt.title("Top 10 Genres of Movies",size=18)
plt.show()
# Out:
# R        6377
# NR       5474
# PG-13    2979
# PG       2168
# G         676
# NC17       38
# Name: content_rating, dtype: int64

# %% [markdown]
# This scatter plot shows all the ratings of the movies and where they are rated the most, in this plot the audience count, tomatometer critics count and tomato fresh critics count as well as the tomatometer rotten critics count are all placed together to show how the movies are rated and where most ratings stand for all the critics.

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('rotten_tomatoes_movies.csv')

fig, ax = plt.subplots(2, figsize=(10, 6))
ax[0].scatter(x = df['tomatometer_fresh_critics_count'], y = df['tomatometer_rotten_critics_count'])
ax[0].set_xlabel("Audience count and tomatoeter critics count")
ax[0].set_ylabel("Count")

ax[1].scatter(x = df['audience_count'], y = df['tomatometer_rotten_critics_count'])
ax[1].set_xlabel("Overall count")
ax[1].set_ylabel("Count")

plt.show()

# %% [markdown]
# This chart shows the top movies in each genre,the top genre is based on the number of movies all of the movies in the database.

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
import numpy as np 
import os 
import pandas as pd 
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")

df1 = pd.read_csv('rotten_tomatoes_movies.csv',delimiter = ',')
df1.head(10)
plt.figure(figsize=(10,6))
fig = sns.countplot(df1["genres"].head(10),color = 'coral')
fig.set_xlabel("genres",size=15)
fig.set_ylabel("Movie Count",size=15)
fig.set_xticklabels(fig.get_xticklabels(),rotation=6)
plt.title('Top Movies in each genre',size = 20)
plt.show()

# %% [markdown]
# This plot shows the runtimes of all movies and the average of all, this shows the that the average movie last longer than 1h30m with few under and above those times.

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
import numpy as np 
import os
import pandas as pd 
import seaborn as sns


import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")

df1 = pd.read_csv('rotten_tomatoes_movies.csv',delimiter = ',')
df1.head(10)
plt.figure(figsize=(10,6))
fig = sns.distplot(df1["runtime"],color = 'green')
fig.set_xlabel("runtime",size=15)
fig.set_ylabel("runtime",size=15)
plt.title('Movies Runtime',size = 20)
plt.show()

# %% [markdown]
# this chart shows the Top audience_rating based on runtime and shows that more run time the movie has a better rating has depending on all the critics.

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing
import seaborn as sns
import warnings

df1 = pd.read_csv('rotten_tomatoes_movies.csv',delimiter = ',')

# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Top audience_rating based on runtime")
 
# Bar chart showing which genre made the most money
sns.barplot(x=df.audience_rating.head(10), y=df['runtime'].head(10))

# Add label for vertical axis
plt.ylabel("Movie Runtime")
df1.head(10)
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
# 5                             m/10000_bc
# 6                     m/1000121-39_steps
# 7                  m/1000123-310_to_yuma
# 8                      m/10002008-charly
# 9              m/1000204-abraham_lincoln
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
# 5                                        10,000 B.C.
# 6                                       The 39 Steps
# 7                                       3:10 to Yuma
# ...

# %% [markdown]
# In this dataframe the tomameter rating, tomameter count and audience rating are all placed together to show the average which explains how they are related to each other.

# %%
import matplotlib.pyplot as plt
df2 = pd.read_csv('rotten_tomatoes_movies.csv',delimiter = ',')
df2 = pd.DataFrame(
    {
        "tomatometer_rating": np.random.randn(1000) + 1,
        "tomatometer_count": np.random.randn(1000),
        "audience_rating": np.random.randn(1000) - 1,
    },
    columns=["tomatometer_rating", "tomatometer_count", "audience_rating"],
)

plt.figure();
df2.plot.hist(alpha=0.5);

# %% [markdown]
# # ●	 Content Rating:
# This line plot will utilize content rating across the different production companies. You should be able to toggle over the plot and view the exact rating.

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

df = pd.read_csv('rotten_tomatoes_movies.csv').head(10)

fig = go.Figure(go.Scatter(x = df['content_rating'], y = df['production_company'],
                  name='Content Rating Across Companies'))

fig.update_layout(title='Content Rating Across Production Companies',
                   plot_bgcolor='rgb(220, 220,220)',
                   showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
